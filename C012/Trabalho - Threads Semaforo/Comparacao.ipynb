# %% [markdown]
# # Sem semaforo

# %%
import threading
import random
import time

class ContaSemProtecao:
    def __init__(self, saldo_inicial=1000):
        self.saldo = saldo_inicial
        self.total_sacado = 0

    def consultar_saldo(self):
        return self.saldo

    def sacar(self, valor):
        if self.saldo >= valor:
            print("Thread", threading.current_thread().name, ": Verificou saldo de R$", self.saldo, "para saque de R$", valor)
            saldo_atual = self.saldo
            time.sleep(0.05)
            self.saldo = saldo_atual - valor
            self.total_sacado += valor
            print("Thread", threading.current_thread().name, ": Saque de R$", valor, "realizado. Novo saldo: R$", self.saldo)
            return True
        else:
            print("Thread", threading.current_thread().name, ": Tentou sacar R$", valor, "mas saldo insuficiente: R$", self.saldo)
            return False

def executar_saque_concorrente(conta, num_saques):
    for _ in range(num_saques):
        valor = random.randint(300, 500)
        conta.sacar(valor)

def demonstrar_sobrecarga():
    conta = ContaSemProtecao(saldo_inicial=1000)
    print("Saldo inicial da conta: R$", conta.consultar_saldo())

    threads = []
    num_threads = 10
    saques_por_thread = 3

    for i in range(num_threads):
        t = threading.Thread(target=executar_saque_concorrente, args=(conta, saques_por_thread), name="Cliente-" + str(i+1))
        threads.append(t)

    for t in threads:
        t.start()

    for t in threads:
        t.join()

    print("============================================================")
    print("⚠️  RESULTADO DA SIMULAÇÃO:")
    print("Saldo inicial: R$", 1000)
    print("Total sacado: R$", conta.total_sacado)
    print("Saldo final:", "\033[91mR$" + str(conta.consultar_saldo()) + "\033[0m")

    if conta.saldo < 0:
        print("❗ RACE CONDITION DETECTADA: Saldo ficou NEGATIVO! Exemplo de erro grave em sistemas concorrentes.")
    elif conta.total_sacado > 1000:
        print("❗ RACE CONDITION DETECTADA: Foram sacados R$", conta.total_sacado, "de uma conta com apenas R$1000!")
    else:
        print("✅ Nenhuma inconsistência detectada.")
    print("============================================================")

if __name__ == "__main__":
    print("============================================================")
    demonstrar_sobrecarga()
# Out:
# ============================================================
# Saldo inicial da conta: R$ 1000
# Thread Cliente-1 : Verificou saldo de R$ 1000 para saque de R$ 361
# Thread Cliente-2 : Verificou saldo de R$ 1000 para saque de R$ 391
# Thread Cliente-3 : Verificou saldo de R$ 1000 para saque de R$ 347
# Thread Cliente-4 : Verificou saldo de R$ 1000 para saque de R$ 456
# Thread Cliente-5 : Verificou saldo de R$ 1000 para saque de R$ 346
# Thread Cliente-6 : Verificou saldo de R$ 1000 para saque de R$ 440
# Thread Cliente-7 : Verificou saldo de R$ 1000 para saque de R$ 394
# Thread Cliente-8 : Verificou saldo de R$ 1000 para saque de R$ 336
# Thread Cliente-9 : Verificou saldo de R$ 1000 para saque de R$ 304
# Thread Cliente-10 : Verificou saldo de R$ 1000 para saque de R$ 337
# Thread Cliente-1 : Saque de R$ 361 realizado. Novo saldo: R$ 639
# Thread Cliente-1 : Verificou saldo de R$ 639 para saque de R$ 427
# Thread Cliente-2 : Saque de R$ 391 realizado. Novo saldo: R$ 609
# Thread Cliente-2 : Verificou saldo de R$ 609 para saque de R$ 429
# Thread Cliente-4 : Saque de R$ 456 realizado. Novo saldo: R$ 544
# Thread Cliente-4 : Verificou saldo de R$ 544 para saque de R$ 414
# Thread Cliente-3 : Saque de R$ 347 realizado. Novo saldo: R$ 653
# Thread Cliente-3 : Verificou saldo de R$ 653 para saque de R$ 430
# Thread Cliente-6 : Saque de R$ 440 realizado. Novo saldo: R$ 560
# Thread Cliente-6 : Verificou saldo de R$ 560 para saque de R$ 488
# Thread Cliente-5 : Saque de R$ 346 realizado. Novo saldo: R$ 654
# Thread Cliente-5 : Verificou saldo de R$ 654 para saque de R$ 415
# Thread Cliente-7 : Saque de R$ 394 realizado. Novo saldo: R$ 606
# Thread Cliente-7 : Verificou saldo de R$ 606 para saque de R$ 317
# Thread Cliente-8 : Saque de R$ 336 realizado. Novo saldo: R$ 664
# Thread Cliente-8 : Verificou saldo de R$ 664 para saque de R$ 404
# Thread Cliente-9 : Saque de R$ 304 realizado. Novo saldo: R$ 696
# Thread Cliente-9 : Verificou saldo de R$ 696 para saque de R$ 449
# Thread Cliente-10 : Saque de R$ 337 realizado. Novo saldo: R$ 663
# Thread Cliente-10 : Verificou saldo de R$ 663 para saque de R$ 341
# Thread Cliente-4 : Saque de R$ 414 realizado. Novo saldo: R$ 130
# Thread Cliente-4 : Tentou sacar R$ 387 mas saldo insuficiente: R$ 130
# Thread Cliente-3 : Saque de R$ 430 realizado. Novo saldo: R$ 223
# Thread Cliente-3 : Tentou sacar R$ 491 mas saldo insuficiente: R$ 223
# Thread Cliente-2 : Saque de R$ 429 realizado. Novo saldo: R$ 180
# Thread Cliente-2 : Tentou sacar R$ 483 mas saldo insuficiente: R$ 180
# Thread Cliente-1 : Saque de R$ 427 realizado. Novo saldo: R$ 212
# Thread Cliente-1 : Tentou sacar R$ 348 mas saldo insuficiente: R$ 212
# Thread Cliente-7 : Saque de R$ 317 realizado. Novo saldo: R$ 289
# Thread Cliente-7 : Tentou sacar R$ 448 mas saldo insuficiente: R$ 289
# Thread Cliente-5 : Saque de R$ 415 realizado. Novo saldo: R$ 239
# Thread Cliente-5 : Tentou sacar R$ 309 mas saldo insuficiente: R$ 239
# Thread Cliente-8 : Saque de R$ 404 realizado. Novo saldo: R$ 260
# Thread Cliente-8 : Tentou sacar R$ 362 mas saldo insuficiente: R$ 260
# Thread Cliente-6 : Saque de R$ 488 realizado. Novo saldo: R$ 72
# Thread Cliente-6 : Tentou sacar R$ 434 mas saldo insuficiente: R$ 72
# Thread Cliente-10 : Saque de R$ 341 realizado. Novo saldo: R$ 322
# Thread Cliente-10 : Tentou sacar R$ 439 mas saldo insuficiente: R$ 322
# Thread Cliente-9 : Saque de R$ 449 realizado. Novo saldo: R$ 247
# Thread Cliente-9 : Tentou sacar R$ 337 mas saldo insuficiente: R$ 247
# ============================================================
# ⚠️  RESULTADO DA SIMULAÇÃO:
# Saldo inicial: R$ 1000
# Total sacado: R$ 7826
# Saldo final: R$247
# ❗ RACE CONDITION DETECTADA: Foram sacados R$ 7826 de uma conta com apenas R$1000!
# ============================================================

# %% [markdown]
# # Com semaforo

# %%
import threading
import random
import time

class ContaComSemaforo:
    def __init__(self, saldo_inicial=1000):
        self.saldo = saldo_inicial
        self.total_sacado = 0
        self.semaforo = threading.Semaphore()  # Semáforo binário (mutex)

    def consultar_saldo(self):
        return self.saldo

    def sacar(self, valor):
        self.semaforo.acquire()  # Início da seção crítica
        try:
            if self.saldo >= valor:
                print("Thread", threading.current_thread().name, ": Verificou saldo de R$", self.saldo, "para saque de R$", valor)
                saldo_atual = self.saldo
                time.sleep(0.05)
                self.saldo = saldo_atual - valor
                self.total_sacado += valor
                print("Thread", threading.current_thread().name, ": Saque de R$", valor, "realizado. Novo saldo: R$", self.saldo)
                return True
            else:
                print("Thread", threading.current_thread().name, ": Tentou sacar R$", valor, "mas saldo insuficiente: R$", self.saldo)
                return False
        finally:
            self.semaforo.release()  # Fim da seção crítica

def executar_saque_concorrente(conta, num_saques):
    for _ in range(num_saques):
        valor = random.randint(300, 500)
        conta.sacar(valor)

def demonstrar_execucao_segura():
    conta = ContaComSemaforo(saldo_inicial=1000)
    print("Saldo inicial da conta: R$", conta.consultar_saldo())

    threads = []
    num_threads = 10
    saques_por_thread = 3

    for i in range(num_threads):
        t = threading.Thread(target=executar_saque_concorrente, args=(conta, saques_por_thread), name="Cliente-" + str(i+1))
        threads.append(t)

    for t in threads:
        t.start()

    for t in threads:
        t.join()

    print("============================================================")
    print("✅ RESULTADO DA SIMULAÇÃO COM SEMÁFORO (SINCRONIZADO):")
    print("Saldo inicial: R$", 1000)
    print("Total sacado: R$", conta.total_sacado)

    # Exibindo o saldo final em verde
    print("\033[32mSaldo final: R$", conta.consultar_saldo(), "\033[0m")

    if conta.saldo < 0:
        print("❌ ERRO: Saldo ficou NEGATIVO! Mesmo com semáforo, algo está errado.")
    elif conta.total_sacado > 1000:
        print("❌ ERRO: Foram sacados R$", conta.total_sacado, "de uma conta com apenas R$1000!")
    else:
        print("✅ Execução segura")
    print("============================================================")

if __name__ == "__main__":

    demonstrar_execucao_segura()
# Out:
# Saldo inicial da conta: R$ 1000
# Thread Cliente-1 : Verificou saldo de R$ 1000 para saque de R$ 485
# Thread Cliente-1 : Saque de R$ 485 realizado. Novo saldo: R$ 515
# Thread Cliente-1 : Verificou saldo de R$ 515 para saque de R$ 391
# Thread Cliente-1 : Saque de R$ 391 realizado. Novo saldo: R$ 124
# Thread Cliente-1 : Tentou sacar R$ 340 mas saldo insuficiente: R$ 124
# Thread Cliente-3 : Tentou sacar R$ 309 mas saldo insuficiente: R$ 124
# Thread Cliente-3 : Tentou sacar R$ 340 mas saldo insuficiente: R$ 124
# Thread Cliente-3 : Tentou sacar R$ 443 mas saldo insuficiente: R$ 124
# Thread Cliente-4 : Tentou sacar R$ 392 mas saldo insuficiente: R$ 124
# Thread Cliente-4 : Tentou sacar R$ 348 mas saldo insuficiente: R$ 124
# Thread Cliente-4 : Tentou sacar R$ 430 mas saldo insuficiente: R$ 124
# Thread Cliente-6 : Tentou sacar R$ 365 mas saldo insuficiente: R$ 124
# Thread Cliente-6 : Tentou sacar R$ 495 mas saldo insuficiente: R$ 124
# Thread Cliente-6 : Tentou sacar R$ 353 mas saldo insuficiente: R$ 124
# Thread Cliente-7 : Tentou sacar R$ 327 mas saldo insuficiente: R$ 124
# Thread Cliente-7 : Tentou sacar R$ 456 mas saldo insuficiente: R$ 124
# Thread Cliente-7 : Tentou sacar R$ 416 mas saldo insuficiente: R$ 124
# Thread Cliente-8 : Tentou sacar R$ 331 mas saldo insuficiente: R$ 124
# Thread Cliente-8 : Tentou sacar R$ 307 mas saldo insuficiente: R$ 124
# Thread Cliente-8 : Tentou sacar R$ 493 mas saldo insuficiente: R$ 124
# Thread Cliente-9 : Tentou sacar R$ 392 mas saldo insuficiente: R$ 124
# Thread Cliente-9 : Tentou sacar R$ 403 mas saldo insuficiente: R$ 124
# Thread Cliente-9 : Tentou sacar R$ 491 mas saldo insuficiente: R$ 124
# Thread Cliente-10 : Tentou sacar R$ 368 mas saldo insuficiente: R$ 124
# Thread Cliente-10 : Tentou sacar R$ 470 mas saldo insuficiente: R$ 124
# Thread Cliente-10 : Tentou sacar R$ 366 mas saldo insuficiente: R$ 124
# Thread Cliente-5 : Tentou sacar R$ 490 mas saldo insuficiente: R$ 124
# Thread Cliente-5 : Tentou sacar R$ 368 mas saldo insuficiente: R$ 124
# Thread Cliente-5 : Tentou sacar R$ 464 mas saldo insuficiente: R$ 124
# Thread Cliente-2 : Tentou sacar R$ 474 mas saldo insuficiente: R$ 124
# Thread Cliente-2 : Tentou sacar R$ 408 mas saldo insuficiente: R$ 124
# Thread Cliente-2 : Tentou sacar R$ 364 mas saldo insuficiente: R$ 124
# ============================================================
# ✅ RESULTADO DA SIMULAÇÃO COM SEMÁFORO (SINCRONIZADO):
# Saldo inicial: R$ 1000
# Total sacado: R$ 876
# Saldo final: R$ 124
# ✅ Execução segura
# ============================================================
