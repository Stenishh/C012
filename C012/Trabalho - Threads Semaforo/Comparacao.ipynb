# %% [markdown]
# # Semaforo

# %%
import threading
import random
import time

class ContaComSemaforo:
    def __init__(self, saldo_inicial=1000):
        self.saldo = saldo_inicial
        self.total_sacado = 0
        self.semaforo = threading.Semaphore()  # Semáforo binário (mutex)

    def consultar_saldo(self):
        return self.saldo

    def sacar(self, valor):
        self.semaforo.acquire()  # Início da seção crítica
        try:
            if self.saldo >= valor:
                print("Thread", threading.current_thread().name, ": Verificou saldo de R$", self.saldo, "para saque de R$", valor)
                saldo_atual = self.saldo
                time.sleep(0.05)
                self.saldo = saldo_atual - valor
                self.total_sacado += valor
                print("Thread", threading.current_thread().name, ": Saque de R$", valor, "realizado. Novo saldo: R$", self.saldo)
                return True
            else:
                print("Thread", threading.current_thread().name, ": Tentou sacar R$", valor, "mas saldo insuficiente: R$", self.saldo)
                return False
        finally:
            self.semaforo.release()  # Fim da seção crítica

def executar_saque_concorrente(conta, num_saques):
    for _ in range(num_saques):
        valor = random.randint(300, 500)
        conta.sacar(valor)

def demonstrar_execucao_segura():
    conta = ContaComSemaforo(saldo_inicial=1000)
    print("Saldo inicial da conta: R$", conta.consultar_saldo())

    threads = []
    num_threads = 10
    saques_por_thread = 3

    for i in range(num_threads):
        t = threading.Thread(target=executar_saque_concorrente, args=(conta, saques_por_thread), name="Cliente-" + str(i+1))
        threads.append(t)

    for t in threads:
        t.start()

    for t in threads:
        t.join()

    print("============================================================")
    print("✅ RESULTADO DA SIMULAÇÃO COM SEMÁFORO (SINCRONIZADO):")
    print("Saldo inicial: R$", 1000)
    print("Total sacado: R$", conta.total_sacado)
    print("Saldo final: R$", conta.consultar_saldo())

    if conta.saldo < 0:
        print("❌ ERRO: Saldo ficou NEGATIVO! Mesmo com semáforo, algo está errado.")
    elif conta.total_sacado > 1000:
        print("❌ ERRO: Foram sacados R$", conta.total_sacado, "de uma conta com apenas R$1000!")
    else:
        print("✅ Execução segura: Nenhuma inconsistência detectada.")
    print("============================================================")

if __name__ == "__main__":
    print("🔐 DEMONSTRAÇÃO COM SEMÁFORO: ACESSO SEGURO À CONTA")
    demonstrar_execucao_segura()
# Out:
# 🔐 DEMONSTRAÇÃO COM SEMÁFORO: ACESSO SEGURO À CONTA
# Saldo inicial da conta: R$ 1000
# Thread Cliente-1 : Verificou saldo de R$ 1000 para saque de R$ 467
# Thread Cliente-1 : Saque de R$ 467 realizado. Novo saldo: R$ 533
# Thread Cliente-1 : Verificou saldo de R$ 533 para saque de R$ 415
# Thread Cliente-1 : Saque de R$ 415 realizado. Novo saldo: R$ 118
# Thread Cliente-1 : Tentou sacar R$ 455 mas saldo insuficiente: R$ 118
# Thread Cliente-3 : Tentou sacar R$ 390 mas saldo insuficiente: R$ 118
# Thread Cliente-3 : Tentou sacar R$ 315 mas saldo insuficiente: R$ 118
# Thread Cliente-3 : Tentou sacar R$ 442 mas saldo insuficiente: R$ 118
# Thread Cliente-4 : Tentou sacar R$ 320 mas saldo insuficiente: R$ 118
# Thread Cliente-4 : Tentou sacar R$ 313 mas saldo insuficiente: R$ 118
# Thread Cliente-4 : Tentou sacar R$ 332 mas saldo insuficiente: R$ 118
# Thread Cliente-5 : Tentou sacar R$ 471 mas saldo insuficiente: R$ 118
# Thread Cliente-5 : Tentou sacar R$ 307 mas saldo insuficiente: R$ 118
# Thread Cliente-5 : Tentou sacar R$ 324 mas saldo insuficiente: R$ 118
# Thread Cliente-6 : Tentou sacar R$ 323 mas saldo insuficiente: R$ 118
# Thread Cliente-6 : Tentou sacar R$ 302 mas saldo insuficiente: R$ 118
# Thread Cliente-6 : Tentou sacar R$ 327 mas saldo insuficiente: R$ 118
# Thread Cliente-7 : Tentou sacar R$ 318 mas saldo insuficiente: R$ 118
# Thread Cliente-7 : Tentou sacar R$ 332 mas saldo insuficiente: R$ 118
# Thread Cliente-7 : Tentou sacar R$ 375 mas saldo insuficiente: R$ 118
# Thread Cliente-8 : Tentou sacar R$ 433 mas saldo insuficiente: R$ 118
# Thread Cliente-8 : Tentou sacar R$ 349 mas saldo insuficiente: R$ 118
# Thread Cliente-8 : Tentou sacar R$ 485 mas saldo insuficiente: R$ 118
# Thread Cliente-9 : Tentou sacar R$ 430 mas saldo insuficiente: R$ 118
# Thread Cliente-9 : Tentou sacar R$ 461 mas saldo insuficiente: R$ 118
# Thread Cliente-9 : Tentou sacar R$ 363 mas saldo insuficiente: R$ 118
# Thread Cliente-10 : Tentou sacar R$ 408 mas saldo insuficiente: R$ 118
# Thread Cliente-10 : Tentou sacar R$ 433 mas saldo insuficiente: R$ 118
# Thread Cliente-10 : Tentou sacar R$ 383 mas saldo insuficiente: R$ 118
# Thread Cliente-2 : Tentou sacar R$ 486 mas saldo insuficiente: R$ 118
# Thread Cliente-2 : Tentou sacar R$ 444 mas saldo insuficiente: R$ 118
# Thread Cliente-2 : Tentou sacar R$ 410 mas saldo insuficiente: R$ 118
# ============================================================
# ✅ RESULTADO DA SIMULAÇÃO COM SEMÁFORO (SINCRONIZADO):
# Saldo inicial: R$ 1000
# Total sacado: R$ 882
# Saldo final: R$ 118
# ✅ Execução segura: Nenhuma inconsistência detectada.
# ============================================================

# %% [markdown]
# # Sem semaforo

# %%
import threading
import random
import time

class ContaSemProtecao:
    def __init__(self, saldo_inicial=1000):
        self.saldo = saldo_inicial
        self.total_sacado = 0

    def consultar_saldo(self):
        return self.saldo

    def sacar(self, valor):
        if self.saldo >= valor:
            print("Thread", threading.current_thread().name, ": Verificou saldo de R$", self.saldo, "para saque de R$", valor)
            saldo_atual = self.saldo
            time.sleep(0.05)
            self.saldo = saldo_atual - valor
            self.total_sacado += valor
            print("Thread", threading.current_thread().name, ": Saque de R$", valor, "realizado. Novo saldo: R$", self.saldo)
            return True
        else:
            print("Thread", threading.current_thread().name, ": Tentou sacar R$", valor, "mas saldo insuficiente: R$", self.saldo)
            return False

def executar_saque_concorrente(conta, num_saques):
    for _ in range(num_saques):
        valor = random.randint(300, 500)
        conta.sacar(valor)

def demonstrar_sobrecarga():
    conta = ContaSemProtecao(saldo_inicial=1000)
    print("Saldo inicial da conta: R$", conta.consultar_saldo())

    threads = []
    num_threads = 10
    saques_por_thread = 3

    for i in range(num_threads):
        t = threading.Thread(target=executar_saque_concorrente, args=(conta, saques_por_thread), name="Cliente-" + str(i+1))
        threads.append(t)

    for t in threads:
        t.start()

    for t in threads:
        t.join()

    print("============================================================")
    print("⚠️  RESULTADO DA SIMULAÇÃO:")
    print("Saldo inicial: R$", 1000)
    print("Total sacado: R$", conta.total_sacado)
    print("Saldo final:", "\033[91mR$" + str(conta.consultar_saldo()) + "\033[0m")

    if conta.saldo < 0:
        print("❗ RACE CONDITION DETECTADA: Saldo ficou NEGATIVO! Exemplo de erro grave em sistemas concorrentes.")
    elif conta.total_sacado > 1000:
        print("❗ RACE CONDITION DETECTADA: Foram sacados R$", conta.total_sacado, "de uma conta com apenas R$1000!")
    else:
        print("✅ Nenhuma inconsistência detectada.")
    print("============================================================")

if __name__ == "__main__":
    print("💣 DEMONSTRAÇÃO DE RACE CONDITION COM SALDO NEGATIVO 💣")
    demonstrar_sobrecarga()
# Out:
# 💣 DEMONSTRAÇÃO DE RACE CONDITION COM SALDO NEGATIVO 💣
# Saldo inicial da conta: R$ 1000
# Thread Cliente-1 : Verificou saldo de R$ 1000 para saque de R$ 431
# Thread Cliente-2 : Verificou saldo de R$ 1000 para saque de R$ 302
# Thread Cliente-3 : Verificou saldo de R$ 1000 para saque de R$ 372
# Thread Cliente-4 : Verificou saldo de R$ 1000 para saque de R$ 380
# Thread Cliente-5 : Verificou saldo de R$ 1000 para saque de R$ 366
# Thread Cliente-6 : Verificou saldo de R$ 1000 para saque de R$ 373
# Thread Cliente-7 : Verificou saldo de R$ 1000 para saque de R$ 491
# Thread Cliente-8 : Verificou saldo de R$ 1000 para saque de R$ 495
# Thread Cliente-9 : Verificou saldo de R$ 1000 para saque de R$ 462
# Thread Cliente-10 : Verificou saldo de R$ 1000 para saque de R$ 474
# Thread Cliente-2 : Saque de R$ 302 realizado. Novo saldo: R$ 698
# Thread Cliente-2 : Verificou saldo de R$ 698 para saque de R$ 491
# Thread Cliente-1 : Saque de R$ 431 realizado. Novo saldo: R$ 569
# Thread Cliente-1 : Verificou saldo de R$ 569 para saque de R$ 334
# Thread Cliente-3 : Saque de R$ 372 realizado. Novo saldo: R$ 628
# Thread Cliente-3 : Verificou saldo de R$ 628 para saque de R$ 455
# Thread Cliente-6 : Saque de R$ 373 realizado. Novo saldo: R$ 627
# Thread Cliente-6 : Verificou saldo de R$ 627 para saque de R$ 434
# Thread Cliente-5 : Saque de R$ 366 realizado. Novo saldo: R$ 634
# Thread Cliente-5 : Verificou saldo de R$ 634 para saque de R$ 421
# Thread Cliente-4 : Saque de R$ 380 realizado. Novo saldo: R$ 620
# Thread Cliente-4 : Verificou saldo de R$ 620 para saque de R$ 326
# Thread Cliente-8 : Saque de R$ 495 realizado. Novo saldo: R$ 505
# Thread Cliente-8 : Verificou saldo de R$ 505 para saque de R$ 484
# Thread Cliente-7 : Saque de R$ 491 realizado. Novo saldo: R$ 509
# Thread Cliente-7 : Verificou saldo de R$ 509 para saque de R$ 312
# Thread Cliente-10 : Saque de R$ 474 realizado. Novo saldo: R$ 526
# Thread Cliente-10 : Verificou saldo de R$ 526 para saque de R$ 316
# Thread Cliente-9 : Saque de R$ 462 realizado. Novo saldo: R$ 538
# Thread Cliente-9 : Verificou saldo de R$ 538 para saque de R$ 401
# Thread Cliente-1 : Saque de R$ 334 realizado. Novo saldo: R$ 235
# Thread Cliente-1 : Tentou sacar R$ 441 mas saldo insuficiente: R$ 235
# Thread Cliente-2 : Saque de R$ 491 realizado. Novo saldo: R$ 207
# Thread Cliente-2 : Tentou sacar R$ 400 mas saldo insuficiente: R$ 207
# Thread Cliente-4 : Saque de R$ 326 realizado. Novo saldo: R$ 294
# Thread Cliente-4 : Tentou sacar R$ 343 mas saldo insuficiente: R$ 294
# Thread Cliente-6 : Saque de R$ 434 realizado. Novo saldo: R$ 193
# Thread Cliente-6 : Tentou sacar R$ 405 mas saldo insuficiente: R$ 193
# Thread Cliente-3 : Saque de R$ 455 realizado. Novo saldo: R$ 173
# Thread Cliente-3 : Tentou sacar R$ 484 mas saldo insuficiente: R$ 173
# Thread Cliente-5 : Saque de R$ 421 realizado. Novo saldo: R$ 213
# Thread Cliente-5 : Tentou sacar R$ 383 mas saldo insuficiente: R$ 213
# Thread Cliente-9 : Saque de R$ 401 realizado. Novo saldo: R$ 137
# Thread Cliente-9 : Tentou sacar R$ 386 mas saldo insuficiente: R$ 137
# Thread Cliente-10 : Saque de R$ 316 realizado. Novo saldo: R$ 210
# Thread Cliente-10 : Tentou sacar R$ 348 mas saldo insuficiente: R$ 210
# Thread Cliente-8 : Saque de R$ 484 realizado. Novo saldo: R$ 21
# Thread Cliente-8 : Tentou sacar R$ 307 mas saldo insuficiente: R$ 21
# Thread Cliente-7 : Saque de R$ 312 realizado. Novo saldo: R$ 197
# Thread Cliente-7 : Tentou sacar R$ 426 mas saldo insuficiente: R$ 197
# ============================================================
# ⚠️  RESULTADO DA SIMULAÇÃO:
# Saldo inicial: R$ 1000
# Total sacado: R$ 8120
# Saldo final: R$197
# ❗ RACE CONDITION DETECTADA: Foram sacados R$ 8120 de uma conta com apenas R$1000!
# ============================================================
